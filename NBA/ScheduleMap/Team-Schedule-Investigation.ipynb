# %% [markdown]
# # `nba_api`: Team Schedule Investigation
#
# Trying to determine which endpoint is best for getting a team's schedule for an entire season.
#
# ## Global Imports

# %%
import pandas as pd
import nba_api as nba

# %% [markdown]
# ## Team Information

# %%
# Import team data
from nba_api.stats.static import teams
nba_teams = teams.get_teams()

# Iterate through the teams
# Print ID and full team name
for tm in nba_teams:    
    team_id = tm['id']
    team_name = tm['full_name']
    print(f'{team_id}\t{team_name}')
# Out:
# 1610612737	Atlanta Hawks
# 1610612738	Boston Celtics
# 1610612739	Cleveland Cavaliers
# 1610612740	New Orleans Pelicans
# 1610612741	Chicago Bulls
# 1610612742	Dallas Mavericks
# 1610612743	Denver Nuggets
# 1610612744	Golden State Warriors
# 1610612745	Houston Rockets
# 1610612746	Los Angeles Clippers
# 1610612747	Los Angeles Lakers
# 1610612748	Miami Heat
# 1610612749	Milwaukee Bucks
# 1610612750	Minnesota Timberwolves
# 1610612751	Brooklyn Nets
# 1610612752	New York Knicks
# 1610612753	Orlando Magic
# 1610612754	Indiana Pacers
# 1610612755	Philadelphia 76ers
# 1610612756	Phoenix Suns
# 1610612757	Portland Trail Blazers
# 1610612758	Sacramento Kings
# 1610612759	San Antonio Spurs
# 1610612760	Oklahoma City Thunder
# 1610612761	Toronto Raptors
# 1610612762	Utah Jazz
# 1610612763	Memphis Grizzlies
# 1610612764	Washington Wizards
# 1610612765	Detroit Pistons
# 1610612766	Charlotte Hornets

# %% [markdown]
# ## TeamGameLog

# %%
# Single Team Game Log Preview
from nba_api.stats.endpoints import teamgamelog
sixers_game_log = teamgamelog.TeamGameLog(season_all='2018-19', season_type_all_star='Regular Season', team_id=1610612755)

# %%
sixers_game_log.get_data_frames()[0].sort_values('Game_ID').head()
# Out:
#        Team_ID     Game_ID     GAME_DATE      MATCHUP WL  W  L  W_PCT  MIN  \
# 47  1610612755  0021800001  OCT 16, 2018    PHI @ BOS  L  0  1  0.000  240
# 46  1610612755  0021800014  OCT 18, 2018  PHI vs. CHI  W  1  1  0.500  240
# 45  1610612755  0021800029  OCT 20, 2018  PHI vs. ORL  W  2  1  0.667  240
# 44  1610612755  0021800049  OCT 23, 2018    PHI @ DET  L  2  2  0.500  265
# 43  1610612755  0021800059  OCT 24, 2018    PHI @ MIL  L  2  3  0.400  240
#
#     FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PTS
# 47   34 ...    0.609     6    41   47   18    8    5   16  20   87
# 46   44 ...    0.900    11    44   55   30   10    8   13  17  127
# 45   45 ...    0.900    13    33   46   33    8    3   10  21  116
# 44   49 ...    0.714     8    40   48   32    3    8   11  24  132
# 43   38 ...    0.700     8    42   50   29    4    5   16  27  108
#
# [5 rows x 27 columns]

# %% [markdown]
# ## TeamInfoCommon

# %%
from nba_api.stats.endpoints import teaminfocommon
sixers_common_info = teaminfocommon.TeamInfoCommon(league_id='00', team_id=1610612755, season_type_nullable='Regular Season', season_nullable='2018-19')

# %%
sixers_common_info.get_data_frames()[0].head()
# Out:
#       TEAM_ID SEASON_YEAR     TEAM_CITY TEAM_NAME TEAM_ABBREVIATION  \
# 0  1610612755     2018-19  Philadelphia     76ers               PHI
#
#   TEAM_CONFERENCE TEAM_DIVISION TEAM_CODE   W   L    PCT  CONF_RANK  DIV_RANK  \
# 0            East      Atlantic    sixers  31  17  0.646          4         2
#
#   MIN_YEAR MAX_YEAR
# 0     1949     2018

# %% [markdown]
# ## ScoreboardV2

# %%
from nba_api.stats.endpoints import scoreboardv2
jan22_scoreboard = scoreboardv2.ScoreboardV2(league_id='00', game_date='2019-01-22', day_offset=0)

# %%
schedule_dict = jan22_scoreboard.get_dict()['resultSets'][0]

# %%
schedule_df = pd.DataFrame(data=schedule_dict['rowSet'], columns=schedule_dict['headers'])

# %%
schedule_df.head()
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID  GAME_STATUS_ID  \
# 0  2019-01-22T00:00:00              1  0021800702               2
# 1  2019-01-22T00:00:00              2  0021800703               2
# 2  2019-01-22T00:00:00              3  0021800704               2
# 3  2019-01-22T00:00:00              4  0021800705               2
#
#   GAME_STATUS_TEXT         GAMECODE  HOME_TEAM_ID  VISITOR_TEAM_ID SEASON  \
# 0          4th Qtr  20190122/SACTOR    1610612761       1610612758   2018
# 1          3rd Qtr  20190122/POROKC    1610612760       1610612757   2018
# 2          2nd Qtr  20190122/LACDAL    1610612742       1610612746   2018
# 3          1st Qtr  20190122/MINPHX    1610612756       1610612750   2018
#
#    LIVE_PERIOD LIVE_PC_TIME NATL_TV_BROADCASTER_ABBREVIATION  \
# 0            4        2:28                              None
# 1            3        11:50                           NBA TV
# 2            2        7:05                              None
# 3            1        5:13                              None
#
#   HOME_TV_BROADCASTER_ABBREVIATION AWAY_TV_BROADCASTER_ABBREVIATION  \
# 0                              TSN                           NBCSCA
# 1                             FSOK                        NBCSNW/BP
# 2                         FSSW-DAL                             FSPT
# 3                              FSA                            FSNTH
#
#   LIVE_PERIOD_TIME_BCAST                  ARENA_NAME  WH_STATUS
# 0            Q4 2:28  -             Scotiabank Arena          0
# 1      Q3 11:50 - NBA TV     Chesapeake Energy Arena          0
# 2            Q2 7:05  -     American Airlines Center          0
# 3            Q1 5:13  -   Talking Stick Resort Arena          0

# %%
future_scoreboard = scoreboardv2.ScoreboardV2(league_id='00', game_date='2019-01-29', day_offset=0)
future_dict = future_scoreboard.get_dict()['resultSets'][0]
future_df = pd.DataFrame(data=future_dict['rowSet'], columns=future_dict['headers'])
future_df.head()
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID  GAME_STATUS_ID  \
# 0  2019-01-29T00:00:00              1  0021800749               1
# 1  2019-01-29T00:00:00              2  0021800750               1
# 2  2019-01-29T00:00:00              3  0021800751               1
# 3  2019-01-29T00:00:00              4  0021800752               1
# 4  2019-01-29T00:00:00              5  0021800753               1
#
#   GAME_STATUS_TEXT         GAMECODE  HOME_TEAM_ID  VISITOR_TEAM_ID SEASON  \
# 0       7:00 pm ET  20190129/WASCLE    1610612739       1610612764   2018
# 1       7:00 pm ET  20190129/MILDET    1610612765       1610612749   2018
# 2       7:00 pm ET  20190129/OKCORL    1610612753       1610612760   2018
# 3       7:30 pm ET  20190129/CHIBKN    1610612751       1610612741   2018
# 4       8:00 pm ET  20190129/NOPHOU    1610612745       1610612740   2018
#
#    LIVE_PERIOD LIVE_PC_TIME NATL_TV_BROADCASTER_ABBREVIATION  \
# 0            0                                          None
# 1            0                                          None
# 2            0                                          None
# 3            0                                          None
# 4            0                                           TNT
#
#   HOME_TV_BROADCASTER_ABBREVIATION AWAY_TV_BROADCASTER_ABBREVIATION  \
# 0                              FSO                           NBCSWA
# 1                              FSD                            FSWIS
# 2                             FSFL                             FSOK
# 3                              YES                              WGN
# 4                         ATTSN-SW                             None
#
#   LIVE_PERIOD_TIME_BCAST            ARENA_NAME  WH_STATUS
# 0            Q0       -    Quicken Loans Arena          0
# 1            Q0       -   Little Caesars Arena          0
# 2            Q0       -           Amway Center          0
# 3            Q0       -        Barclays Center          0
# 4         Q0       - TNT         Toyota Center          0

# %% [markdown]
# ## Using ScoreboardV2 to build out entire schedule

# %% [markdown]
# Build out date range covering 2018-19 NBA Regular Season

# %%
season_dt_range = [dt.strftime('%Y-%m-%d') for dt in pd.date_range('2018-10-16', '2019-04-10')]

# %%
season_dt_range[0], season_dt_range[-1]
# Out:
# ('2018-10-16', '2019-04-10')

# %% [markdown]
# Iterate through date range and pull scoreboard data

# %%
# Empty DataFrame to hold daily information
global_scoreboard_df = pd.DataFrame()

# Pared down column list 
column_list = ['GAME_DATE_EST', 'GAME_STATUS_TEXT', 'GAME_ID', 'HOME_TEAM_ID', 'VISITOR_TEAM_ID', 'SEASON', 'ARENA_NAME']

# For each date...
for dt in season_dt_range:
    
    # Pull data from endpoint as dict for given day
    scoreboard_dict = scoreboardv2.ScoreboardV2(league_id='00', game_date=dt, day_offset=0).get_dict()['resultSets'][0]
    # Convert to local DataFrame
    scoreboard_df = pd.DataFrame(data=scoreboard_dict['rowSet'], columns=scoreboard_dict['headers'])
    # Isolate the pared down column list
    scoreboard_df = scoreboard_df.loc[:, column_list]
    # Append to global DataFrame
    global_scoreboard_df = global_scoreboard_df.append(scoreboard_df)

# %%
global_scoreboard_df.sample(10)
# Out:
#          GAME_DATE_EST GAME_STATUS_TEXT     GAME_ID HOME_TEAM_ID  \
# 6  2018-12-26T00:00:00            Final  0021800508   1610612763
# 1  2019-02-06T00:00:00       8:00 pm ET  0021800805   1610612741
# 0  2018-10-16T00:00:00            Final  0021800001   1610612738
# 0  2019-04-05T00:00:00       7:00 pm ET  0021801180   1610612766
# 6  2019-04-05T00:00:00       8:00 pm ET  0021801186   1610612760
# 3  2019-02-02T00:00:00       7:00 pm ET  0021800778   1610612764
# 6  2018-12-08T00:00:00            Final  0021800384   1610612763
# 2  2019-01-02T00:00:00            Final  0021800556   1610612764
# 3  2018-12-19T00:00:00            Final  0021800458   1610612738
# 7  2019-03-28T00:00:00       8:30 pm ET  0021801129   1610612759
#
#   VISITOR_TEAM_ID SEASON               ARENA_NAME
# 6      1610612739   2018               FedExForum
# 1      1610612740   2018            United Center
# 0      1610612755   2018                TD Garden
# 0      1610612761   2018          Spectrum Center
# 6      1610612765   2018  Chesapeake Energy Arena
# 3      1610612749   2018        Capital One Arena
# 6      1610612747   2018               FedExForum
# 2      1610612737   2018        Capital One Arena
# 3      1610612756   2018                TD Garden
# 7      1610612739   2018              AT&T Center

# %%
global_scoreboard_df.dtypes
# Out:
# GAME_DATE_EST       object
# GAME_STATUS_TEXT    object
# GAME_ID             object
# HOME_TEAM_ID        object
# VISITOR_TEAM_ID     object
# SEASON              object
# ARENA_NAME          object
# dtype: object

# %%
global_scoreboard_df['GAME_ID'] = global_scoreboard_df['GAME_ID'].astype('int64')
global_scoreboard_df['HOME_TEAM_ID'] = global_scoreboard_df['HOME_TEAM_ID'].astype('int64')
global_scoreboard_df['VISITOR_TEAM_ID'] = global_scoreboard_df['VISITOR_TEAM_ID'].astype('int64')
global_scoreboard_df['SEASON'] = global_scoreboard_df['SEASON'].astype('int64')

# %%
global_scoreboard_df.dtypes
# Out:
# GAME_DATE_EST       object
# GAME_STATUS_TEXT    object
# GAME_ID              int64
# HOME_TEAM_ID         int64
# VISITOR_TEAM_ID      int64
# SEASON               int64
# ARENA_NAME          object
# dtype: object

# %% [markdown]
# Create DataFrame with team information
#
# **Team Data Structure:**
# ```
# team = {
#     'id': team_id,
#     'full_name': full_name,
#     'abbreviation': abbreviation,
#     'nickname': nickname,
#     'city': city,
#     'state': state,
#     'year_founded': year_founded,
# }
# ```

# %%
from nba_api.stats.static import teams
team_df = pd.DataFrame(teams.get_teams())
team_df.sample(5)
# Out:
#    abbreviation         city          full_name          id nickname  \
# 14          BKN     Brooklyn      Brooklyn Nets  1610612751     Nets
# 28          DET      Detroit    Detroit Pistons  1610612765  Pistons
# 22          SAS  San Antonio  San Antonio Spurs  1610612759    Spurs
# 25          UTA         Utah          Utah Jazz  1610612762     Jazz
# 1           BOS       Boston     Boston Celtics  1610612738  Celtics
#
#             state  year_founded
# 14       New York          1976
# 28       Michigan          1948
# 22          Texas          1976
# 25           Utah          1974
# 1   Massachusetts          1946

# %%
team_df.dtypes
# Out:
# abbreviation    object
# city            object
# full_name       object
# id               int64
# nickname        object
# state           object
# year_founded     int64
# dtype: object

# %% [markdown]
# Enrich schedule data with home team data

# %%
columns = column_list + ['abbreviation', 'full_name', 'city', 'nickname', 'state']
column_map = {'abbreviation':'HOME_TEAM_ABBR', 'full_name':'HOME_TEAM_NAME', 'city':'HOME_TEAM_CITY', 'nickname':'HOME_TEAM_NICKNAME', 'state':'HOME_TEAM_STATE'}
global_scoreboard_df = (global_scoreboard_df.merge(team_df, left_on='HOME_TEAM_ID', right_on='id')
                                            .loc[:, columns]
                                            .rename(columns=column_map))

# %% [markdown]
# Enrich schedule data with visitor team data

# %%
columns = list(global_scoreboard_df.columns) + ['abbreviation', 'full_name', 'city', 'nickname', 'state']
column_map = {'abbreviation':'VISITOR_TEAM_ABBR', 'full_name':'VISITOR_TEAM_NAME', 'city':'VISITOR_TEAM_CITY', 'nickname':'VISITOR_TEAM_NICKNAME', 'state':'VISITOR_TEAM_STATE'}
global_scoreboard_df = (global_scoreboard_df.merge(team_df, left_on='VISITOR_TEAM_ID', right_on='id')
                                            .loc[:, columns]
                                            .rename(columns=column_map))

# %% [markdown]
# Reorder columns

# %%
list(global_scoreboard_df.columns)
# Out:
# ['GAME_DATE_EST',
#  'GAME_STATUS_TEXT',
#  'GAME_ID',
#  'HOME_TEAM_ID',
#  'VISITOR_TEAM_ID',
#  'SEASON',
#  'ARENA_NAME',
#  'HOME_TEAM_ABBR',
#  'HOME_TEAM_NAME',
#  'HOME_TEAM_CITY',
#  'HOME_TEAM_NICKNAME',
#  'HOME_TEAM_STATE',
#  'VISITOR_TEAM_ABBR',
#  'VISITOR_TEAM_NAME',
#  'VISITOR_TEAM_CITY',
#  'VISITOR_TEAM_NICKNAME',
#  'VISITOR_TEAM_STATE']

# %%
reordered_columns = [
    'SEASON',
    'GAME_DATE_EST',
    'GAME_ID',
    'ARENA_NAME',
    'VISITOR_TEAM_ID',
    'VISITOR_TEAM_ABBR',
    'VISITOR_TEAM_NAME',
    'VISITOR_TEAM_CITY',
    'VISITOR_TEAM_NICKNAME',
    'VISITOR_TEAM_STATE',
    'HOME_TEAM_ID',
    'HOME_TEAM_ABBR',
    'HOME_TEAM_NAME',
    'HOME_TEAM_CITY',
    'HOME_TEAM_NICKNAME',
    'HOME_TEAM_STATE',   
]
global_scoreboard_df = global_scoreboard_df.loc[:, reordered_columns]

# %%
global_scoreboard_df.sample(5)
# Out:
#      SEASON        GAME_DATE_EST   GAME_ID               ARENA_NAME  \
# 114    2018  2019-03-08T00:00:00  21800980            United Center
# 651    2018  2019-03-22T00:00:00  21801086           Staples Center
# 860    2018  2019-01-15T00:00:00  21800653         State Farm Arena
# 955    2018  2019-03-16T00:00:00  21801039              AT&T Center
# 850    2018  2018-12-22T00:00:00  21800485  Vivint Smart Home Arena
#
#      VISITOR_TEAM_ID VISITOR_TEAM_ABBR       VISITOR_TEAM_NAME  \
# 114       1610612765               DET         Detroit Pistons
# 651       1610612751               BKN           Brooklyn Nets
# 860       1610612760               OKC   Oklahoma City Thunder
# 955       1610612757               POR  Portland Trail Blazers
# 850       1610612760               OKC   Oklahoma City Thunder
#
#     VISITOR_TEAM_CITY VISITOR_TEAM_NICKNAME VISITOR_TEAM_STATE  HOME_TEAM_ID  \
# 114           Detroit               Pistons           Michigan    1610612741
# 651          Brooklyn                  Nets           New York    1610612747
# 860     Oklahoma City               Thunder           Oklahoma    1610612737
# 955          Portland         Trail Blazers             Oregon    1610612759
# 850     Oklahoma City               Thunder           Oklahoma    1610612762
#
#     HOME_TEAM_ABBR      HOME_TEAM_NAME HOME_TEAM_CITY HOME_TEAM_NICKNAME  \
# 114            CHI       Chicago Bulls        Chicago              Bulls
# 651            LAL  Los Angeles Lakers    Los Angeles             Lakers
# 860            ATL       Atlanta Hawks        Atlanta              Hawks
# 955            SAS   San Antonio Spurs    San Antonio              Spurs
# 850            UTA           Utah Jazz           Utah               Jazz
#
#     HOME_TEAM_STATE
# 114        Illinois
# 651      California
# 860         Atlanta
# 955           Texas
# 850            Utah

# %% [markdown]
# Dump to CSV

# %%
global_scoreboard_df.to_csv('./nba_schedule_2018_19.csv', sep='|', header=True, index=False, encoding='utf-8')

# %% [markdown]
# ## Get the Coordinates of the NBA Cities

# %%
# !pip install geopy
# Out:
# Collecting geopy
#   Downloading https://files.pythonhosted.org/packages/a8/5c/ca78a17b2c6fe1179e9221c9280bb5d8caaf048a631ed72caed40c52de24/geopy-1.18.1-py2.py3-none-any.whl (98kB)
#     100% |████████████████████████████████| 102kB 1.3MB/s a 0:00:01
# Collecting geographiclib<2,>=1.49 (from geopy)
#   Downloading https://files.pythonhosted.org/packages/5b/ac/4f348828091490d77899bc74e92238e2b55c59392f21948f296e94e50e2b/geographiclib-1.49.tar.gz
# Building wheels for collected packages: geographiclib
#   Running setup.py bdist_wheel for geographiclib ... done
#   Stored in directory: /Users/leon/Library/Caches/pip/wheels/99/45/d1/14954797e2a976083182c2e7da9b4e924509e59b6e5c661061
# Successfully built geographiclib
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.49 geopy-1.18.1

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent='NBA-Schedule')

# %%
# Group the team city names in the dataset 
city_list = (global_scoreboard_df.loc[:,['HOME_TEAM_CITY', 'HOME_TEAM_STATE', 'HOME_TEAM_NAME']]
                                 .groupby(['HOME_TEAM_CITY','HOME_TEAM_STATE', 'HOME_TEAM_NAME'])
                                 .count()
                                 .reset_index())

# %%
city_list
# Out:
#    HOME_TEAM_CITY       HOME_TEAM_STATE          HOME_TEAM_NAME
# 0         Atlanta               Atlanta           Atlanta Hawks
# 1          Boston         Massachusetts          Boston Celtics
# 2        Brooklyn              New York           Brooklyn Nets
# 3       Charlotte        North Carolina       Charlotte Hornets
# 4         Chicago              Illinois           Chicago Bulls
# 5       Cleveland                  Ohio     Cleveland Cavaliers
# 6          Dallas                 Texas        Dallas Mavericks
# 7          Denver              Colorado          Denver Nuggets
# 8         Detroit              Michigan         Detroit Pistons
# 9    Golden State            California   Golden State Warriors
# 10        Houston                 Texas         Houston Rockets
# 11        Indiana               Indiana          Indiana Pacers
# 12    Los Angeles            California    Los Angeles Clippers
# 13    Los Angeles            California      Los Angeles Lakers
# 14        Memphis             Tennessee       Memphis Grizzlies
# 15          Miami               Florida              Miami Heat
# 16      Milwaukee             Wisconsin         Milwaukee Bucks
# 17      Minnesota             Minnesota  Minnesota Timberwolves
# 18    New Orleans             Louisiana    New Orleans Pelicans
# 19       New York              New York         New York Knicks
# 20  Oklahoma City              Oklahoma   Oklahoma City Thunder
# 21        Orlando               Florida           Orlando Magic
# 22   Philadelphia          Pennsylvania      Philadelphia 76ers
# 23        Phoenix               Arizona            Phoenix Suns
# 24       Portland                Oregon  Portland Trail Blazers
# 25     Sacramento            California        Sacramento Kings
# 26    San Antonio                 Texas       San Antonio Spurs
# 27        Toronto               Ontario         Toronto Raptors
# 28           Utah                  Utah               Utah Jazz
# 29     Washington  District of Columbia      Washington Wizards

# %%
import time

# Lists to store latitude and longitude values
lats = []
lons = []

# Iterate through each row of the city DataFrame
for ix, row in city_list.iterrows():
    
    # Create city, state string
    # (manually handle Atlanta, Atlanta and Golden State, California datapoints)
    if row.HOME_TEAM_CITY == 'Atlanta':
        city_comma_state = f"{row.HOME_TEAM_CITY}, Georgia"
    elif row.HOME_TEAM_CITY == 'Golden State':
        city_comma_state = f"Oakland, {row.HOME_TEAM_STATE}"
    else:
        city_comma_state = f"{row.HOME_TEAM_CITY}, {row.HOME_TEAM_STATE}"
    
    # Get location data
    location = geolocator.geocode(city_comma_state)
    print(f"{city_comma_state} - {location.latitude}, {location.longitude}")
    
    # Store latitude and longitude information 
    lats.append(location.latitude)
    lons.append(location.longitude)
    
    # Pause for a few seconds
    time.sleep(3)
# Out:
# Atlanta, Georgia - 33.7490987, -84.3901849
# Boston, Massachusetts - 42.3602534, -71.0582912
# Brooklyn, New York - 40.6501038, -73.9495823
# Charlotte, North Carolina - 35.2270869, -80.8431268
# Chicago, Illinois - 41.8755616, -87.6244212
# Cleveland, Ohio - 41.5051613, -81.6934446
# Dallas, Texas - 32.7762719, -96.7968559
# Denver, Colorado - 39.7392364, -104.9848623
# Detroit, Michigan - 42.3315509, -83.0466403
# Oakland, California - 37.8044557, -122.2713563
# Houston, Texas - 29.7589382, -95.3676974
# Indiana, Indiana - 40.6214551, -79.1525349
# Los Angeles, California - 34.0536834, -118.2427669
# Los Angeles, California - 34.0536834, -118.2427669
# Memphis, Tennessee - 35.1490215, -90.0516285
# Miami, Florida - 25.7742658, -80.1936589
# Milwaukee, Wisconsin - 43.0349931, -87.922497
# Minnesota, Minnesota - 44.98632495, -93.179462592857
# New Orleans, Louisiana - 29.9499323, -90.0701156
# New York, New York - 40.7308619, -73.9871558
# Oklahoma City, Oklahoma - 35.4729886, -97.5170536
# Orlando, Florida - 28.5421097, -81.3790388
# Philadelphia, Pennsylvania - 39.9524152, -75.1635755
# Phoenix, Arizona - 33.4485866, -112.0773456
# Portland, Oregon - 45.5202471, -122.6741949
# Sacramento, California - 38.5815719, -121.4943996
# San Antonio, Texas - 29.4246002, -98.4951405
# Toronto, Ontario - 43.653963, -79.387207
# Utah, Utah - 40.0881195, -111.6238946
# Washington, District of Columbia - 38.8950092, -77.0365625

# %%
# Add lats and lons to city DataFrame
city_list.loc[:, 'lat'] = lats
city_list.loc[:, 'lon'] = lons

# %%
city_list
# Out:
#    HOME_TEAM_CITY       HOME_TEAM_STATE          HOME_TEAM_NAME        lat  \
# 0         Atlanta               Atlanta           Atlanta Hawks  33.749099
# 1          Boston         Massachusetts          Boston Celtics  42.360253
# 2        Brooklyn              New York           Brooklyn Nets  40.650104
# 3       Charlotte        North Carolina       Charlotte Hornets  35.227087
# 4         Chicago              Illinois           Chicago Bulls  41.875562
# 5       Cleveland                  Ohio     Cleveland Cavaliers  41.505161
# 6          Dallas                 Texas        Dallas Mavericks  32.776272
# 7          Denver              Colorado          Denver Nuggets  39.739236
# 8         Detroit              Michigan         Detroit Pistons  42.331551
# 9    Golden State            California   Golden State Warriors  37.804456
# 10        Houston                 Texas         Houston Rockets  29.758938
# 11        Indiana               Indiana          Indiana Pacers  40.621455
# 12    Los Angeles            California    Los Angeles Clippers  34.053683
# 13    Los Angeles            California      Los Angeles Lakers  34.053683
# 14        Memphis             Tennessee       Memphis Grizzlies  35.149022
# 15          Miami               Florida              Miami Heat  25.774266
# 16      Milwaukee             Wisconsin         Milwaukee Bucks  43.034993
# 17      Minnesota             Minnesota  Minnesota Timberwolves  44.986325
# 18    New Orleans             Louisiana    New Orleans Pelicans  29.949932
# 19       New York              New York         New York Knicks  40.730862
# 20  Oklahoma City              Oklahoma   Oklahoma City Thunder  35.472989
# 21        Orlando               Florida           Orlando Magic  28.542110
# 22   Philadelphia          Pennsylvania      Philadelphia 76ers  39.952415
# 23        Phoenix               Arizona            Phoenix Suns  33.448587
# 24       Portland                Oregon  Portland Trail Blazers  45.520247
# 25     Sacramento            California        Sacramento Kings  38.581572
# 26    San Antonio                 Texas       San Antonio Spurs  29.424600
# 27        Toronto               Ontario         Toronto Raptors  43.653963
# 28           Utah                  Utah               Utah Jazz  40.088119
# 29     Washington  District of Columbia      Washington Wizards  38.895009
#
#            lon
# 0   -84.390185
# 1   -71.058291
# 2   -73.949582
# 3   -80.843127
# 4   -87.624421
# 5   -81.693445
# 6   -96.796856
# 7  -104.984862
# 8   -83.046640
# 9  -122.271356
# 10  -95.367697
# 11  -79.152535
# 12 -118.242767
# 13 -118.242767
# 14  -90.051629
# 15  -80.193659
# 16  -87.922497
# 17  -93.179463
# 18  -90.070116
# 19  -73.987156
# 20  -97.517054
# 21  -81.379039
# 22  -75.163575
# 23 -112.077346
# 24 -122.674195
# 25 -121.494400
# 26  -98.495141
# 27  -79.387207
# 28 -111.623895
# 29  -77.036563

# %%
import plotly.offline as pyo
import plotly.graph_objs as go

pyo.init_notebook_mode(connected=True)

data = [go.Scattergeo(
            lat=city_list['lat'],
            lon=city_list['lon'],
            locationmode="USA-states",
            text=city_list['HOME_TEAM_NAME'],
            mode='markers')
       ]

layout = go.Layout(title='NBA Team Locations',
                   geo={'scope': 'usa'}
                  )

fig = go.Figure(data=data, layout=layout)
pyo.iplot(fig)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <div id="2c331ac9-018d-44de-bb74-e37fa44dc6f8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("2c331ac9-018d-44de-bb74-e37fa44dc6f8", [{"lat": [33.7490987, 42.3602534, 40.6501038, 35.2270869, 41.8755616, 41.5051613, 32.7762719, 39.7392364, 42.3315509, 37.8044557, 29.7589382, 40.6214551, 34.0536834, 34.0536834, 35.1490215, 25.7742658, 43.0349931, 44.98632495, 29.9499323, 40.7308619, 35.4729886, 28.5421097, 39.9524152, 33.4485866, 45.5202471, 38.5815719, 29.4246002, 43.653963, 40.0881195, 38.8950092], "locationmode": "USA-states", "lon": [-84.3901849, -71.0582912, -73.9495823, -80.8431268, -87.6244212, -81.6934446, -96.7968559, -104.9848623, -83.0466403, -122.2713563, -95.3676974, -79.1525349, -118.2427669, -118.2427669, -90.0516285, -80.1936589, -87.922497, -93.179462592857, -90.0701156, -73.9871558, -97.5170536, -81.3790388, -75.1635755, -112.0773456, -122.6741949, -121.4943996, -98.4951405, -79.387207, -111.6238946, -77.0365625], "mode": "markers", "text": ["Atlanta Hawks", "Boston Celtics", "Brooklyn Nets", "Charlotte Hornets", "Chicago Bulls", "Cleveland Cavaliers", "Dallas Mavericks", "Denver Nuggets", "Detroit Pistons", "Golden State Warriors", "Houston Rockets", "Indiana Pacers", "Los Angeles Clippers", "Los Angeles Lakers", "Memphis Grizzlies", "Miami Heat", "Milwaukee Bucks", "Minnesota Timberwolves", "New Orleans Pelicans", "New York Knicks", "Oklahoma City Thunder", "Orlando Magic", "Philadelphia 76ers", "Phoenix Suns", "Portland Trail Blazers", "Sacramento Kings", "San Antonio Spurs", "Toronto Raptors", "Utah Jazz", "Washington Wizards"], "type": "scattergeo", "uid": "8aeb2039-6fd4-4297-abec-da0b8fd29d08"}], {"geo": {"scope": "usa"}, "title": {"text": "NBA Team Locations"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("2c331ac9-018d-44de-bb74-e37fa44dc6f8"));});</script>
